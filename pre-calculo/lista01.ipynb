# %% [markdown]
# Exercicio 2

# %%
import matplotlib.pyplot as plt
import numpy as np

def PrintPlot(x,y):
    plt.plot(x, y,'r')

# %% [markdown]
# Letra A

# %%
x = np.linspace(-5,5,100)
y = 2*x +3

PrintPlot(x, y)

# %% [markdown]
# Letra B

# %%
x = np.linspace(-5,5,100)
y = -x + 4

PrintPlot(x, y)

# %%
x = np.linspace(-5,5,100)
y = x**2

PrintPlot(x, y) S

# %% [markdown]
# Letra D

# %%
x = np.linspace(-5,5,100)
y = -2*x**2 +4

PrintPlot(x, y)
